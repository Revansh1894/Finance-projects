# %%
import pandas as pd          
import numpy as np          
import matplotlib.pyplot as plt  
import yfinance as yf       
# %matplotlib inline
import warnings                   
warnings.filterwarnings("ignore")

# %%
# let us get some data. One thing to be careful about data is that  for reliability model should use similar condition data for example
#I cannot use a model trained on crisis data to predict normal market scenario stats. Let us begin after end of 2008 crisisdf=yf.download("RELIANCE.NS",,start="2011-01-01")
df=yf.download("SPY",start="2011-01-01")
df['returns']=df.Close.pct_change()
df['returns']=np.log1p(df['returns'])*100 # converting into continuously compounded returns in %
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03  126.709999  127.599998  125.699997  127.050003   99.999397
# 2011-01-04  127.330002  127.370003  126.190002  126.980003   99.944298
# 2011-01-05  126.580002  127.720001  126.459999  127.639999  100.463791
# 2011-01-06  127.690002  127.830002  127.010002  127.389999  100.266998
# 2011-01-07  127.559998  127.769997  126.150002  127.139999  100.070229
#
#                Volume   returns
# Date
# 2011-01-03  138725200       NaN
# 2011-01-04  137409700 -0.055111
# 2011-01-05  133975300  0.518418
# 2011-01-06  122519000 -0.196055
# 2011-01-07  156034600 -0.196441

# %% [markdown]
# ## plotting stock data as candlesticks

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY


df_reset = df.loc['2023-09':'2023-09'].reset_index()
df_reset['date_ax'] = df_reset['Date'].apply(lambda date: date2num(date))
df_values = [tuple(vals) for vals in df_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)        # major ticks on the mondays
alldays = DayLocator()              # minor ticks on the days
weekFormatter = DateFormatter('%b %d')  # e.g., Jan 12
dayFormatter = DateFormatter('%d')      # e.g., 12

#Plot it
fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2)
ax.xaxis.set_major_locator(mondays)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(weekFormatter)

candlestick_ohlc(ax, df_values, width=0.6, colorup='g',colordown='r');

# %%
df.fillna(method='bfill',inplace=True)
df.head()    #cleaning data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03  126.709999  127.599998  125.699997  127.050003   99.999405
# 2011-01-04  127.330002  127.370003  126.190002  126.980003   99.944313
# 2011-01-05  126.580002  127.720001  126.459999  127.639999  100.463776
# 2011-01-06  127.690002  127.830002  127.010002  127.389999  100.266998
# 2011-01-07  127.559998  127.769997  126.150002  127.139999  100.070229
#
#                Volume   returns
# Date
# 2011-01-03  138725200 -0.055111
# 2011-01-04  137409700 -0.055111
# 2011-01-05  133975300  0.518418
# 2011-01-06  122519000 -0.196055
# 2011-01-07  156034600 -0.196441

# %% [markdown]
# https://github.com/BessieChen/Python-for-Financial-Analysis-and-Algorithmic-Trading/blob/master/07-Stock-Market-Analysis-Capstone-Project/01-M-Stock%20Market%20Analysis%20Project%20SOLUTIONS.ipynb
# in 7.1

# %%
df.index # already in DatetimeIndex form if not we could
#use df.index=pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['2011-01-03', '2011-01-04', '2011-01-05', '2011-01-06',
#                '2011-01-07', '2011-01-10', '2011-01-11', '2011-01-12',
#                '2011-01-13', '2011-01-14',
#                ...
#                '2023-09-22', '2023-09-25', '2023-09-26', '2023-09-27',
#                '2023-09-28', '2023-09-29', '2023-10-02', '2023-10-03',
#                '2023-10-04', '2023-10-05'],
#               dtype='datetime64[ns]', name='Date', length=3211, freq=None)

# %%
df.plot(subplots=True);

# %%
# returns looking very congested resampling it to downscale intomonthly data
df_monthly=df.resample("MS").mean()

# %% [markdown]
# https://stackoverflow.com/questions/54840047/attributeerror-datetimeindexresampler-object-has-no-attribute-rolling

# %%
df_monthly.loc[df_monthly.index[0]:df_monthly.index[5]]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-01  128.240001  128.730000  127.545000  128.270501  100.960040
# 2011-02-01  131.972633  132.689473  131.489475  132.301580  104.132846
# 2011-03-01  130.706087  131.420000  129.862175  130.641304  103.020348
# 2011-04-01  133.137000  133.661999  132.567501  133.193500  105.290285
# 2011-05-01  134.124286  134.756190  133.345713  134.074284  105.986550
# 2011-06-01  129.041818  129.815454  128.222274  128.954545  102.168852
#
#                   Volume   returns
# Date
# 2011-01-01  1.430157e+08  0.060984
# 2011-02-01  1.484249e+08  0.179724
# 2011-03-01  2.081504e+08 -0.018324
# 2011-04-01  1.406359e+08  0.142750
# 2011-05-01  1.589337e+08 -0.053704
# 2011-06-01  2.141106e+08 -0.099814

# %%
df=df_monthly
df["returns"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# from first look it looks like some seasonility is there but we will analyze that later
# lets us look at acf and pacf first
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df["returns"],lags=10)
plot_pacf(df["returns"],lags=10)
plt.show()

# %% [markdown]
# using PACF plot we can guess coeffecients or AR process

# %% [markdown]
# # Augmented dickey fuller test
# A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are all constant over time. In adf test the null hypothesis is that data is non stationary. If p value is smaller than our confidence level we may reject null hypothesis and
# conclude that data is in fact stationary.So p value should be small.

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df['returns'])
print('Test Stat: {}\np value: {}'.format(result[0], result[1]))
# Out:
# Test Stat: -10.388399110134074
# p value: 2.0511950428963964e-18

# %%
# building arma models now
from statsmodels.tsa.arima.model import ARIMA
df.index = pd.DatetimeIndex(df.index).to_period('M')
model_ma1=ARIMA(df['returns'],order=(0,0,2))
ma1_results=model_ma1.fit()
ma1_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                  154
# Model:                 ARIMA(0, 0, 2)   Log Likelihood                  31.406
# Date:                Fri, 06 Oct 2023   AIC                            -54.813
# Time:                        18:01:04   BIC                            -42.665
# Sample:                    01-31-2011   HQIC                           -49.878
#                          - 10-31-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0373      0.014      2.588      0.010       0.009       0.065
# ma.L1         -0.1709      0.066     -2.579      0.010      -0.301      -0.041
# ma.L2         -0.1036      0.072     -1.439      0.150      -0.245       0.038
# sigma2         0.0389      0.004      9.565      0.000       0.031       0.047
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                37.15
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.80   Skew:                            -0.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# but we might have overfitted our model so better to split it into training and test data
from sklearn.model_selection import train_test_split
train,test=train_test_split(df['returns'],test_size=0.2,shuffle=False)
model_ma2=ARIMA(train,order=(0,0,2))
ma2_results=model_ma2.fit()
ma2_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                  123
# Model:                 ARIMA(0, 0, 2)   Log Likelihood                  35.355
# Date:                Fri, 06 Oct 2023   AIC                            -62.710
# Time:                        18:01:04   BIC                            -51.461
# Sample:                    01-31-2011   HQIC                           -58.141
#                          - 03-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0439      0.013      3.428      0.001       0.019       0.069
# ma.L1         -0.1506      0.071     -2.121      0.034      -0.290      -0.011
# ma.L2         -0.2170      0.097     -2.244      0.025      -0.407      -0.027
# sigma2         0.0329      0.003      9.835      0.000       0.026       0.039
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                65.49
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.16   Skew:                            -1.16
# Prob(H) (two-sided):                  0.02   Kurtosis:                         5.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ma2_results.plot_diagnostics(figsize=(15, 12))
plt.show() # shows behavior of residuals over time it should be ensured that residuals resemble white noise

# %%
# now predicting test data values with it
start = len(train) 
end = len(train) + len(test) - 1
start
# Out:
# 123

# %%
#let us plot the results

predictions=ma2_results.predict(start,end)
#predictions=pd.DataFrame(predictions,index=test.index,columns=['Prediction'])


pred=pd.DataFrame(predictions)
pred.set_index(test.index,inplace=True)# if gap in data it sets index same as test datset so easy to
#compare
pred.rename(columns={"predicted_mean":"prediction"},inplace=True)
pred
# Out:
#          prediction
# Date
# 2021-04   -0.008989
# 2021-05    0.009528
# 2021-06    0.043933
# 2021-07    0.043933
# 2021-08    0.043933
# 2021-09    0.043933
# 2021-10    0.043933
# 2021-11    0.043933
# 2021-12    0.043933
# 2022-01    0.043933
# 2022-02    0.043933
# 2022-03    0.043933
# 2022-04    0.043933
# 2022-05    0.043933
# 2022-06    0.043933
# 2022-07    0.043933
# 2022-08    0.043933
# 2022-09    0.043933
# 2022-10    0.043933
# 2022-11    0.043933
# 2022-12    0.043933
# 2023-01    0.043933
# 2023-02    0.043933
# 2023-03    0.043933
# 2023-04    0.043933
# 2023-05    0.043933
# 2023-06    0.043933
# 2023-07    0.043933
# 2023-08    0.043933
# 2023-09    0.043933
# 2023-10    0.043933

# %%
train.plot(legend=True)
test.plot(legend=True)
pred['prediction'].plot(legend=True)
plt.show()

# %%
df["returns"].index
# Out:
# PeriodIndex(['2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#              '2011-07', '2011-08', '2011-09', '2011-10',
#              ...
#              '2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06',
#              '2023-07', '2023-08', '2023-09', '2023-10'],
#             dtype='period[M]', name='Date', length=154)

# %%
# data is monthly and may contain seasonal and holiday effects lets check by ETS analysis
from statsmodels.tsa.seasonal import seasonal_decompose 
ETS= seasonal_decompose(df["returns"], model = "add",period=12)
breakdown=pd.DataFrame({'seasonal': ETS.seasonal,"trend":ETS.trend,"residual":ETS.resid})
breakdown.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
k=pd.DataFrame(df["returns"])
k.index
# Out:
# PeriodIndex(['2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#              '2011-07', '2011-08', '2011-09', '2011-10',
#              ...
#              '2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06',
#              '2023-07', '2023-08', '2023-09', '2023-10'],
#             dtype='period[M]', name='Date', length=154)

# %%
# may be seasonal factors should be incorporated for best results
from pmdarima import auto_arima 
auto_arima(df['returns'],seasonal=True, m=12,max_p=7, max_d=5,max_q=7, max_P=4, max_D=4,max_Q=4,max_order=6).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  154
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                  30.685
# Date:                Fri, 06 Oct 2023   AIC                            -55.370
# Time:                        18:01:13   BIC                            -46.259
# Sample:                    01-31-2011   HQIC                           -51.670
#                          - 10-31-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0370      0.016      2.328      0.020       0.006       0.068
# ma.L1         -0.1918      0.063     -3.059      0.002      -0.315      -0.069
# sigma2         0.0393      0.004      9.672      0.000       0.031       0.047
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                31.77
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.87   Skew:                            -0.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
# based on above ouput we can create optimal SARIMAX model
model=SARIMAX(train,order=(1,0,0), seasonal_order = (0,0,0,12))
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                  123
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                  28.716
# Date:                Fri, 06 Oct 2023   AIC                            -53.432
# Time:                        18:01:13   BIC                            -47.807
# Sample:                    01-31-2011   HQIC                           -51.147
#                          - 03-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0423      0.061     -0.689      0.491      -0.163       0.078
# sigma2         0.0367      0.004      9.612      0.000       0.029       0.044
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.55   Jarque-Bera (JB):                25.09
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.25   Skew:                            -0.63
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred = result.predict(start = len(train), end = len(df)-1)
k=pd.DataFrame(pred,index=test.index)
test.plot(legend=True)
k['predicted_mean'].plot(legend=True)
train.plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # forecast using prophet

# %%
from prophet import Prophet

# %%
df_pr=pd.DataFrame(df['returns'])
#ds_pr.reset_index(inplace=True)
# ds_pr.rename(columns={"Date":"ds"},inplace=True)
# ds_pr['ds']=pd.to_datetime(ds_pr['ds'])
df_pr['ds']=df_pr.index.astype(str)
df_pr['ds']=pd.to_datetime(df_pr['ds'])
df_pr.rename(columns={"returns":"y"},inplace=True)

# %%
train,test=train_test_split(df_pr,test_size=0.2,shuffle=False)
m = Prophet()
m.fit(train)
future = m.make_future_dataframe(periods=len(test),freq='M')
prophet_pred = m.predict(future)
# Out:
# 18:01:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:01:14 - cmdstanpy - INFO - Chain [1] done processing

# %%
len(prophet_pred)
# Out:
# 154

# %%
prophetpred=pd.DataFrame({"Pred" : prophet_pred[-len(test):]["yhat"]})
prophetpred.index=test.index
prophetpred.head()
# Out:
#              Pred
# Date
# 2021-04  0.154732
# 2021-05  0.052689
# 2021-06  0.073838
# 2021-07  0.139959
# 2021-08  0.036757

# %%
train
# Out:
#                 y         ds
# Date
# 2011-01  0.060984 2011-01-01
# 2011-02  0.179724 2011-02-01
# 2011-03 -0.018324 2011-03-01
# 2011-04  0.142750 2011-04-01
# 2011-05 -0.053704 2011-05-01
# ...           ...        ...
# 2020-11  0.516287 2020-11-01
# 2020-12  0.146023 2020-12-01
# 2021-01 -0.053909 2021-01-01
# 2021-02  0.144347 2021-02-01
# 2021-03  0.178822 2021-03-01
#
# [123 rows x 2 columns]

# %%
# fig, ax = plt.subplots()
# train['y'].plot(linestyle="--")
# test['y'].plot(linestyle="-.")
# prophetpred['Pred'].plot(linestyle="-")
# ax.legend(["train", "test", "test-predicted"])
train['y'].plot(label="train")
test['y'].plot(label= "test",linestyle="-.")
prophetpred['Pred'].plot(label="test-predicted",linestyle="-")
plt.legend()
