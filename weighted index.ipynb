# %%
import pandas as pd

# %%
number =pd.read_csv("ind30_m_nfirms.csv",index_col=0,parse_dates=True)
size=pd.read_csv("ind30_m_size.csv",index_col=0,parse_dates=True) # this size means avg.value
number.index=pd.to_datetime(number.index,format="%Y%m").to_period("M")
size.index=pd.to_datetime(size.index,format="%Y%m").to_period("M")
# Out:
# C:\Users\91957\AppData\Local\Temp\ipykernel_19872\4201018737.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   number =pd.read_csv("ind30_m_nfirms.csv",index_col=0,parse_dates=True)
# C:\Users\91957\AppData\Local\Temp\ipykernel_19872\4201018737.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   size=pd.read_csv("ind30_m_size.csv",index_col=0,parse_dates=True) # this size means avg.value

# %%
number.head()
# Out:
#          Food   Beer   Smoke  Games  Books  Hshld  Clths  Hlth   Chems  Txtls  \
# 1926-07     43      3     16      7      2      8     12      7     17     13
# 1926-08     43      3     16      7      2      8     12      7     17     13
# 1926-09     43      3     16      7      2      8     12      7     17     13
# 1926-10     43      3     16      7      2      8     12      7     17     13
# 1926-11     43      3     16      7      2      8     12      7     17     13
#
#          ...  Telcm  Servs  BusEq  Paper  Trans  Whlsl  Rtail  Meals  Fin    \
# 1926-07  ...      5      3      7      6     74      2     33      6     12
# 1926-08  ...      5      3      7      6     74      2     33      6     12
# 1926-09  ...      5      3      7      6     74      2     33      6     12
# 1926-10  ...      5      3      7      6     74      2     33      6     12
# 1926-11  ...      5      3      7      6     74      2     33      6     12
#
#          Other
# 1926-07      4
# ...

# %%
returns=pd.read_csv('C:/Users/91957/Downloads/ind49_m_vw_rets.csv',header=0,index_col=0,parse_dates=True)/100
returns.index=pd.to_datetime(returns.index,format="%Y%m").to_period("M")
# Out:
# C:\Users\91957\AppData\Local\Temp\ipykernel_19872\1934457326.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   returns=pd.read_csv('C:/Users/91957/Downloads/ind49_m_vw_rets.csv',header=0,index_col=0,parse_dates=True)/100

# %%
returns.head()
# Out:
#           Agric   Food    Soda    Beer    Smoke   Toys    Fun     Books  \
# 1926-07  0.0237  0.0012 -0.9999 -0.0519  0.0129  0.0865  0.0250  0.5021
# 1926-08  0.0223  0.0268 -0.9999  0.2703  0.0650  0.1681 -0.0076  0.4298
# 1926-09 -0.0057  0.0158 -0.9999  0.0402  0.0126  0.0833  0.0642 -0.0491
# 1926-10 -0.0046 -0.0368 -0.9999 -0.0331  0.0106 -0.0140 -0.0509  0.0537
# 1926-11  0.0675  0.0626 -0.9999  0.0729  0.0455  0.0000  0.0182 -0.0640
#
#           Hshld   Clths  ...   Boxes   Trans   Whlsl   Rtail   Meals   Banks  \
# 1926-07 -0.0048  0.0808  ...  0.0770  0.0194 -0.2379  0.0007  0.0187  0.0461
# 1926-08 -0.0358 -0.0251  ... -0.0238  0.0488  0.0539 -0.0075 -0.0013  0.1183
# 1926-09  0.0073 -0.0051  ... -0.0554  0.0006 -0.0787  0.0025 -0.0056 -0.0175
# 1926-10 -0.0468  0.0012  ... -0.0508 -0.0264 -0.1538 -0.0220 -0.0411 -0.1182
# 1926-11 -0.0054  0.0187  ...  0.0384  0.0160  0.0467  0.0652  0.0433 -0.0297
#
#           Insur   RlEst   Fin     Other
# ...

# %%
# market cap of each industry
marketcap=size*number
marketcap.head()
# Out:
#            Food   Beer     Smoke   Games  Books   Hshld   Clths   Hlth   \
# 1926-07  1547.14  21.36   955.52  184.87  24.04  178.16  220.32  178.64
# 1926-08  1552.30  20.25   967.52  190.19  26.66  177.04  237.96  180.60
# 1926-09  1591.00  25.74  1024.48  191.10  29.34  169.44  231.48  187.11
# 1926-10  1597.02  26.76  1030.72  201.32  28.84  169.84  228.36  188.09
# 1926-11  1542.84  25.86  1041.28  191.66  31.58  161.12  228.36  185.78
#
#            Chems  Txtls  ...    Telcm  Servs   BusEq   Paper    Trans  Whlsl  \
# 1926-07   979.03  80.34  ...  1751.80  40.80  396.90  212.10  4951.34   2.38
# 1926-08  1056.21  80.60  ...  1766.35  44.25  404.18  227.16  5031.26   1.80
# 1926-09  1114.01  87.23  ...  1804.80  45.15  417.27  220.92  5255.48   1.90
# 1926-10  1163.99  88.66  ...  1820.80  45.90  416.64  208.62  5241.42   1.76
# 1926-11  1106.02  88.92  ...  1818.70  44.67  411.18  196.80  5087.50   1.48
#
#            Rtail  Meals   Fin     Other
# ...

# %%
marketcap['total']=marketcap.sum(axis='columns')
import matplotlib.pyplot as plt
marketcap['total'].plot()
# Out:
# <Axes: >

# %%
marketcap.loc['192607']  #correct way to access it '1926-07' gives error
# Out:
# Food      1547.14
# Beer        21.36
# Smoke      955.52
# Games      184.87
# Books       24.04
# Hshld      178.16
# Clths      220.32
# Hlth       178.64
# Chems      979.03
# Txtls       80.34
# Cnstr      280.70
# Steel     2185.20
# FabPr      521.93
# ElcEq     1218.58
# Autos     1854.45
# Carry      536.90
# Mines      388.36
# Coal       324.16
# Oil       3989.97
# Util      1705.62
# Telcm     1751.80
# Servs       40.80
# BusEq      396.90
# Paper      212.10
# Trans     4951.34
# Whlsl        2.38
# Rtail     1539.45
# Meals       64.92
# Fin        225.96
# Other       97.00
# total    26657.94
# Name: 1926-07, dtype: float64

# %%
marketcap_weights=marketcap.divide(marketcap['total'],axis='rows') 
# understand why rows came and not columns
marketcap_weights.loc['1926'].sum('columns')
#marketcap_weights.loc['192607'].sum('columns') not valid
# Out:
# 1926-07    2.0
# 1926-08    2.0
# 1926-09    2.0
# 1926-10    2.0
# 1926-11    2.0
# 1926-12    2.0
# Freq: M, dtype: float64

# %%
marketcap_weights=marketcap_weights.drop(columns='total')
marketcap_weights
# Out:
#             Food      Beer      Smoke     Games     Books     Hshld     Clths  \
# 1926-07  0.058037  0.000801  0.035844  0.006935  0.000902  0.006683  0.008265
# 1926-08  0.056578  0.000738  0.035264  0.006932  0.000972  0.006453  0.008673
# 1926-09  0.056699  0.000917  0.036510  0.006810  0.001046  0.006038  0.008249
# 1926-10  0.056920  0.000954  0.036736  0.007175  0.001028  0.006053  0.008139
# 1926-11  0.056725  0.000951  0.038285  0.007047  0.001161  0.005924  0.008396
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.021873  0.008309  0.008222  0.011997  0.001168  0.014569  0.009720
# 2018-09  0.021005  0.007873  0.007515  0.011923  0.001076  0.014427  0.009874
# 2018-10  0.020661  0.007862  0.007831  0.011851  0.001052  0.014606  0.010000
# 2018-11  0.022649  0.008403  0.009178  0.010810  0.001066  0.015702  0.009761
# 2018-12  0.022832  0.008763  0.008291  0.010589  0.001083  0.016477  0.009510
#
# ...

# %%
marketcap_weights.columns=marketcap_weights.columns.str.strip()
marketcap_weights['Fin'].plot()
# Out:
# <Axes: >

# %%
# now calculating net market return of this weighted index
net_return=(marketcap_weights*returns).sum('columns')

# %%
net_return.plot(figsize=(10,5),title="weighted returns of index",xlabel="time",ylabel='returns') #df.plot
# Out:
# <Axes: title={'center': 'weighted returns of index'}, xlabel='time', ylabel='returns'>

# %%
net_return
# Out:
# 1926-07   -0.002429
# 1926-08   -0.006581
# 1926-09   -0.020808
# 1926-10   -0.049352
# 1926-11   -0.009710
#              ...
# 2018-08    0.010979
# 2018-09    0.001516
# 2018-10   -0.021558
# 2018-11    0.008296
# 2018-12   -0.028588
# Freq: M, Length: 1110, dtype: float64

# %%
(1+net_return)['2000':].cumprod()
# Out:
# 2000-01    0.975983
# 2000-02    0.963603
# 2000-03    0.991508
# 2000-04    0.982190
# 2000-05    0.968151
#              ...
# 2018-08    1.575195
# 2018-09    1.577583
# 2018-10    1.543573
# 2018-11    1.556379
# 2018-12    1.511884
# Freq: M, Length: 228, dtype: float64

# %%
wealth_index=100*(1+net_return)['2000':].cumprod()
wealth_index.plot()
# Out:
# <Axes: >

# %%
wealth_index.plot(label="wealth_index",legend=True)
wealth_index.rolling(window=36).mean().plot(label="wealth index 36m avg.",) 

# mean of past 36 months returns
# Out:
# <Axes: >
